# %% [markdown]
# <a href="https://colab.research.google.com/github/osmarbraz/exemplos_spacy/blob/main/Exemplo_SpacyColab_pt_br.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplo uso Spacy com Modelo em Português
# Exemplo do uso Spacy Python Library com execução através do Google Colaboratory.<br>
#
# Funciona no Jupiter Notebook com algumas modificações.
#
# Site ferramenta: https://spacy.io/
#
# Tutorial<br>
# https://medium.com/@van3ssabandeira/o-famoso-spacy-90afb683b6fe

# %% [markdown]
# # 0 Preparação do ambiente
# Preparação do ambiente para executar o spacy.

# %% [markdown]
# ##Tratamento de logs

# %%
#biblioteca de logging
import logging

#Formato da mensagem
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Parâmetros
#
# Parâmetros da execução do teste
#
# * sm = small model (não possui vocabulário de palavras)
# * md = medium model
# * lg = large model
#
# https://spacy.io/models/en

# %%
# Definição do nome do arquivo do modelo
#MODELO_SPACY = 'pt_core_news_sm'
#MODELO_SPACY = 'pt_core_news_md'
MODELO_SPACY = 'pt_core_news_lg'

logging.info('Parâmetros definidos!')
# Out:
# INFO:root:Parâmetros definidos!

# %% [markdown]
# # 1 Instalação

# %% [markdown]
# Instala o spacy no notebook. O site para instalação está em https://spacy.io/usage.
#
# No Jupiter Notebook executar através "Anaconda Prompt".

# %%
# Instala o spacy
# !pip install -U pip==25.3 setuptools==80.9.0 wheel==0.45.1
# Out:
# Requirement already satisfied: pip==25.3 in /usr/local/lib/python3.12/dist-packages (25.3)
# Requirement already satisfied: setuptools==80.9.0 in /usr/local/lib/python3.12/dist-packages (80.9.0)
# Requirement already satisfied: wheel==0.45.1 in /usr/local/lib/python3.12/dist-packages (0.45.1)

# %%
# Instala a última versão disponível
#!pip install -U spacy

# Instala uma versão específica
# !pip install -U spacy==3.8.11
# Out:
# Requirement already satisfied: spacy==3.8.11 in /usr/local/lib/python3.12/dist-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.8.11) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.11) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.11) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.11) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.11) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.11) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.11) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.11) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy==3.8.11) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy==3.8.11) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy==3.8.11) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy==3.8.11) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy==3.8.11) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy==3.8.11) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy==3.8.11) (3.0.3)

# %% [markdown]
# # 2 Execução

# %% [markdown]
# ##Baixa o modelo em português.
#
# Outras linguagens podem ser consultadas em:<br>
# https://spacy.io/usage/models#languages

# %%
# Baixa automaticamente o arquivo do modelo
# !python -m spacy download $MODELO_SPACY

logging.info('Modelo descarregado !')
# Out:
# Collecting pt-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.8.0/pt_core_news_lg-3.8.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 41.4 MB/s  0:00:10
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# INFO:root:Modelo descarregado !

# %% [markdown]
# ## Importa as bibliotecas

# %%
# Importando as bibliotecas.
import spacy
from spacy  import displacy

logging.info('Import realizado!')
# Out:
# INFO:root:Import realizado!

# %% [markdown]
# ## Carrega o modelo em português.
#
# Outros modelos estão disponíveis em https://spacy.io/models
#
# Para tornar os modelos compactos e rápidos, os modelos pequenos do spaCy (todos os pacotes que terminam em **sm**(small) não contêm  vetores de palavras e incluem apenas tensores sensíveis ao contexto.

# %%
# Instala somente os pipelines necessários
#nlp = spacy.load(MODELO_SPACY, disable=['tokenizer', 'lemmatizer', 'ner', 'parser', 'textcat', 'custom'])

nlp = spacy.load(MODELO_SPACY)

logging.info('Modelo carregado !')
# Out:
# INFO:root:Modelo carregado !

# %% [markdown]
# # 3 Exemplo sentença 1

# %%
documento = u"Estou bem, mas não tenho certeza se viajarei para São Paulo amanhã às 8:30."

# %% [markdown]
# ##Armazena um texto.

# %%
doc = nlp(documento)
logging.info('Texto armazenado!')
# Out:
# INFO:root:Texto armazenado!

# %% [markdown]
# ##Separando o texto em uma lista de tokens.

# %%
>>> [token.orth_ for token in doc]
# Out:
# ['Estou',
#  'bem',
#  ',',
#  'mas',
#  'não',
#  'tenho',
#  'certeza',
#  'se',
#  'viajarei',
#  'para',
#  'São',
#  'Paulo',
#  'amanhã',
#  'às',
#  '8:30',
#  '.']

# %% [markdown]
# ##Separando o texto em uma lista de palavras

# %%
doc.text.split()
# Out:
# ['Estou',
#  'bem,',
#  'mas',
#  'não',
#  'tenho',
#  'certeza',
#  'se',
#  'viajarei',
#  'para',
#  'São',
#  'Paulo',
#  'amanhã',
#  'às',
#  '8:30.']

# %% [markdown]
# ## Criando uma lista das sentenças

# %%
lista = list(doc.sents)
print("Número de sentenças = ",len(lista))
print(lista)
# Out:
# Número de sentenças =  1
# [Estou bem, mas não tenho certeza se viajarei para São Paulo amanhã às 8:30.]

# %% [markdown]
# ##Verificando se a palavra é um verbo.

# %%
[(token.text, token.pos_ == 'VERB') for token in doc]
# Out:
# [('Estou', False),
#  ('bem', False),
#  (',', False),
#  ('mas', False),
#  ('não', False),
#  ('tenho', True),
#  ('certeza', False),
#  ('se', False),
#  ('viajarei', True),
#  ('para', False),
#  ('São', False),
#  ('Paulo', False),
#  ('amanhã', False),
#  ('às', False),
#  ('8:30', False),
#  ('.', False)]

# %% [markdown]
# ##Identificando o infinitivo dos verbos.

# %%
[(token.text, token.lemma_) for token in doc if token.pos_ == 'VERB']
# Out:
# [('tenho', 'ter'), ('viajarei', 'viajar')]

# %% [markdown]
# ##Verificando se a palavra da sentença é uma pontuação.

# %%
[(token.text, token.is_punct) for token in doc]
# Out:
# [('Estou', False),
#  ('bem', False),
#  (',', True),
#  ('mas', False),
#  ('não', False),
#  ('tenho', False),
#  ('certeza', False),
#  ('se', False),
#  ('viajarei', False),
#  ('para', False),
#  ('São', False),
#  ('Paulo', False),
#  ('amanhã', False),
#  ('às', False),
#  ('8:30', False),
#  ('.', True)]

# %% [markdown]
# ##Identificando as classes gramaticais das palavras.
#
# O significado das classes estão em: https://spacy.io/api/annotation#pos-tagging
#
#
# https://universaldependencies.org/docs/u/pos/

# %%
[(token.text, token.pos_) for token in doc]
# Out:
# [('Estou', 'AUX'),
#  ('bem', 'ADV'),
#  (',', 'PUNCT'),
#  ('mas', 'CCONJ'),
#  ('não', 'ADV'),
#  ('tenho', 'VERB'),
#  ('certeza', 'NOUN'),
#  ('se', 'SCONJ'),
#  ('viajarei', 'VERB'),
#  ('para', 'ADP'),
#  ('São', 'PROPN'),
#  ('Paulo', 'PROPN'),
#  ('amanhã', 'ADV'),
#  ('às', 'ADP'),
#  ('8:30', 'NOUN'),
#  ('.', 'PUNCT')]

# %% [markdown]
# ## Ancestrais

# %%
tokens = [token for token in doc]
tokens[0].is_ancestor(tokens[2])
# Out:
# False

# %% [markdown]
# ##Identificando as sentenças em um texto.

# %% [markdown]
# Mostra as sentenças de um texto.

# %%
for sentencas in doc.sents:
    print(sentencas)
# Out:
# Estou bem, mas não tenho certeza se viajarei para São Paulo amanhã às 8:30.

# %% [markdown]
# ##Identificando as entidades. (NER/Named Entity Recognition)
#
# **Text**: o texto original da entidade.<br>
# **Start**: Índice de início da entidade no Doc.<br>
# **End**: Índice do fim da entidade no Doc.<br>
# **Label**: rótulo da entidade, ou seja, tipo.<br>
#
# https://medium.com/botsbrasil/como-reconhecer-entidades-na-l%C3%ADngua-portuguesa-usando-spacy-8a5ca6f42c4f

# %% [markdown]
# ### Listando as entidades identificadas

# %%
for ent in doc.ents:
   print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# São Paulo 50 59 LOC

# %% [markdown]
# ou

# %%
[(entity, entity.label_) for entity in doc.ents]
# Out:
# [(São Paulo, 'LOC')]

# %% [markdown]
# ### Visualizando o texto marcado

# %%
# Importando as bibliotecas.
import spacy
from spacy  import displacy

displacy.render(doc,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Estou bem, mas não tenho certeza se viajarei para
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     São Paulo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  amanhã às 8:30.</div></span>

# %% [markdown]
# ###Checando similaridade entre as entidades.

# %%
# Retorna as entidades de doc
entities = [entity for entity in doc.ents]

if len(doc.ents) > 1:
  print('Similaridade entre entities[0]=[' + str(entities[0]) + '] e entities[0]=[' + str(entities[0]) + ']: %.4g'%(entities[0].similarity(entities[0]) * 100), "%")
  print('Similaridade entre entities[0]=[' + str(entities[0]) + '] e entities[1]=[' + str(entities[1]) + ']: %.4g'%(entities[0].similarity(entities[1]) * 100), "%")
else:
  print('Similaridade entre entities[0]=[' + str(entities[0]) + '] e entities[0]=[' + str(entities[0]) + ']: %.4g'%(entities[0].similarity(entities[0]) * 100), "%")
# Out:
# Similaridade entre entities[0]=[São Paulo] e entities[0]=[São Paulo]: 100 %

# %% [markdown]
# ## POS tagging / Analisando a sentença
#
# https://medium.com/greyatom/learning-pos-tagging-chunking-in-nlp-85f7f811a8cb
#
# **Text**: o texto original da palavra.<br>
# **Lema**: A forma base da palavra.<br>
# **POS**: A tag simples da parte do discurso. O significado das classes estão em: https://spacy.io/api/annotation#pos-tagging<br>
# **Tag**: A etiqueta detalhada da parte do discurso.<br>
# **Dep**: Dependência sintática, ou seja, a relação entre tokens.<br>
# **Shape**: A forma da palavra - letras maiúsculas, pontuação e dígitos.<br>
# **is alpha**: o token é um caractere alfa?<br>
# **is stop**: o token faz parte de uma lista de paradas, ou seja, as palavras mais comuns do idioma?<br> **bold text**

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,token.shape_,token.is_alpha, token.is_stop)
# Out:
# Estou estar AUX AUX cop Xxxxx True True
# bem bem ADV ADV ROOT xxx True True
# , , PUNCT PUNCT punct , False False
# mas mas CCONJ CCONJ cc xxx True True
# não não ADV ADV advmod xxx True True
# tenho ter VERB VERB conj xxxx True True
# certeza certeza NOUN NOUN obj xxxx True True
# se se SCONJ SCONJ mark xx True True
# viajarei viajar VERB VERB ccomp xxxx True False
# para para ADP ADP case xxxx True True
# São São PROPN PROPN obl Xxx True True
# Paulo Paulo PROPN PROPN flat:name Xxxxx True False
# amanhã amanhã ADV ADV advmod xxxx True False
# às a o ADP ADP case xx True True
# 8:30 8:30 NOUN NOUN obl d:dd False False
# . . PUNCT PUNCT punct . False False

# %% [markdown]
# ou partes

# %%
print([(token.text, token.tag_) for token in doc])
# Out:
# [('Estou', 'AUX'), ('bem', 'ADV'), (',', 'PUNCT'), ('mas', 'CCONJ'), ('não', 'ADV'), ('tenho', 'VERB'), ('certeza', 'NOUN'), ('se', 'SCONJ'), ('viajarei', 'VERB'), ('para', 'ADP'), ('São', 'PROPN'), ('Paulo', 'PROPN'), ('amanhã', 'ADV'), ('às', 'ADP'), ('8:30', 'NOUN'), ('.', 'PUNCT')]

# %% [markdown]
# ## Frequência de POS

# %%
[(token.text, token.pos_) for token in doc]
# Out:
# [('Estou', 'AUX'),
#  ('bem', 'ADV'),
#  (',', 'PUNCT'),
#  ('mas', 'CCONJ'),
#  ('não', 'ADV'),
#  ('tenho', 'VERB'),
#  ('certeza', 'NOUN'),
#  ('se', 'SCONJ'),
#  ('viajarei', 'VERB'),
#  ('para', 'ADP'),
#  ('São', 'PROPN'),
#  ('Paulo', 'PROPN'),
#  ('amanhã', 'ADV'),
#  ('às', 'ADP'),
#  ('8:30', 'NOUN'),
#  ('.', 'PUNCT')]

# %%
def getDicPOSQtde(sentenca):

    # Verifica se o sentenca não foi processado pelo spaCy
  if type(sentenca) is not spacy.tokens.doc.Doc:
      # Realiza o parsing no spacy
      doc = nlp(sentenca)
  else:
      doc = sentenca

  # Retorna inteiros que mapeiam para classes gramaticais
  conta_dicionarios = doc.count_by(spacy.attrs.IDS['POS'])

  # Dicionário com as tags e quantidades
  novodic = dict()

  for pos, qtde in conta_dicionarios.items():
    classe_gramatical = doc.vocab[pos].text
    novodic[classe_gramatical] = qtde

  return novodic

# %%
documento = "O céu está azul e verde."
# Processa sentença no spaCy
doc = nlp(documento)

retorno = getDicPOSQtde(documento)

print(retorno)
# Out:
# {'DET': 1, 'NOUN': 1, 'AUX': 1, 'ADJ': 2, 'CCONJ': 1, 'PUNCT': 1}

# %% [markdown]
# ##Noun Chunking / Substantivos
#
# Os substantivos são "sentenças substantivas de base" - sentenças simples que têm um substantivo como principal. Você pode pensar em blocos de substantivos como um substantivo, além das palavras que descrevem o substantivo - por exemplo, "a luxuosa grama verde" ou "o maior fundo de tecnologia do mundo".
#
# **Text**: o texto original do pedaço do substantivo.<br>
# **Root text**: o texto original da palavra que conecta o pedaço do substantivo ao restante da análise.<br>
# **Root dep**: relação de dependência que conecta a raiz à sua cabeça.<br>
# **Root head text**: o texto do cabeçalho do token raiz.<br>
#
# https://medium.com/greyatom/learning-pos-tagging-chunking-in-nlp-85f7f811a8cb

# %%
#for chunk in doc.noun_chunks:
  #print(chunk.text, chunk.label_, chunk.root.text, chunk.root.dep_,chunk.root.head.text)

# %% [markdown]
# ##Visualizando as dependências
#
# Éo processo de representar as dependências do texto através das relações entre os tokens. Por exemplo: um artigo está ligado a um substantivo, um advérbio modifica um verbo, e assim por diante.
#
# O significado das classes estão em: https://spacy.io/api/annotation#pos-tagging

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 85})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="dd758d4277f449c18aaf327f553c5dae-0" class="displacy" width="560" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="135">céu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="220">está</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="220">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="305">azul</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="390">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="390">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="475">verde.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="475">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd758d4277f449c18aaf327f553c5dae-0-0" stroke-width="2px" d="M70,87.0 C70,44.5 130.0,44.5 130.0,87.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd758d4277f449c18aaf327f553c5dae-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,89.0 L62,77.0 78,77.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd758d4277f449c18aaf327f553c5dae-0-1" stroke-width="2px" d="M155,87.0 C155,2.0 305.0,2.0 305.0,87.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd758d4277f449c18aaf327f553c5dae-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M155,89.0 L147,77.0 163,77.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd758d4277f449c18aaf327f553c5dae-0-2" stroke-width="2px" d="M240,87.0 C240,44.5 300.0,44.5 300.0,87.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd758d4277f449c18aaf327f553c5dae-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240,89.0 L232,77.0 248,77.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd758d4277f449c18aaf327f553c5dae-0-3" stroke-width="2px" d="M410,87.0 C410,44.5 470.0,44.5 470.0,87.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd758d4277f449c18aaf327f553c5dae-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M410,89.0 L402,77.0 418,77.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd758d4277f449c18aaf327f553c5dae-0-4" stroke-width="2px" d="M325,87.0 C325,2.0 475.0,2.0 475.0,87.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd758d4277f449c18aaf327f553c5dae-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M475.0,89.0 L483.0,77.0 467.0,77.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Árvore de Análise da sentença

# %%
# Importando a biblioteca
from nltk import Tree

def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_

[to_nltk_tree(sent.root).pretty_print() for sent in doc.sents]
# Out:
#      azul
#   ____|_________
#  |    |   céu verde
#  |    |    |    |
# está  .    O    e
# [None]

# %% [markdown]
# ## Sentença substantiva
#
# https://realpython.com/natural-language-processing-spacy-python/

# %%
doc = nlp(documento)

# Extrai as sentenças substantivas
#for chunk in doc.noun_chunks:
#   print (chunk)

# %% [markdown]
# ## Localiza verbos
#
# Localiza os verbos e locuções verbais da sentença.
#
# Parâmetro OP:
# - \! = Negação, 0 Vezes
# - \? = Opcional, 0 ou 1 Vez
# - \+ = Requerido, 1 ou mais vezes
# - \* = Vários, 0 ou mais vezes
#
# Simulador em inglês:
# https://explosion.ai/demos/matcher

# %%
import spacy
from spacy.util import filter_spans
from spacy.matcher import Matcher

# (verbo normal como auxilar ou auxilar) + vários verbos auxiliares +verbo principal ou verbo auxiliar
gramaticav1 =  [
                {'POS': 'AUX', 'OP': '?', 'DEP': {'IN': ['aux','aux:pass']}},  #verbo auxiliar
                {'POS': 'VERB', 'OP': '?', 'DEP': {'IN': ['ROOT','aux','xcomp','aux:pass']}},  #verbo normal como auxiliar
                {'POS': 'AUX', 'OP': '*', 'DEP': {'IN': ['aux','xcomp','aux:pass']}},  #verbo auxiliar
                {'POS': 'VERB', 'OP': '+'}, #verbo principal
                {'POS': 'AUX', 'OP': '?', 'DEP': {'IN': ['cop','aux','xcomp','aux:pass']}},  #verbo auxiliar
               ]

# verbo auxiliar + verbo normal como auxiliar + conjunção com preposição + verbo
gramaticav2 =  [
                {'POS': 'AUX', 'OP': '?', 'DEP': {'IN': ['aux','aux:pass']}},  #verbo auxiliar
                {'POS': 'VERB', 'OP': '+', 'DEP': {'IN': ['ROOT']}},  #verbo principal
                {'POS': 'SCONJ', 'OP': '+', 'DEP': {'IN': ['mark']}}, #conjunção com preposição
                {'POS': 'VERB', 'OP': '+', 'DEP': {'IN': ['xcomp']}}, #verbo normal como complementar
               ]

#Somente verbos auxiliares
gramaticav3 =  [
                {'POS': 'AUX', 'OP': '?'},  #Verbos auxiliar
                {'POS': 'AUX', 'OP': '?', 'DEP': {'IN': ['cop']}},  #Verbos auxiliar de ligação (AUX+(cop))
                {'POS': 'ADJ', 'OP': '+', 'DEP': {'IN': ['ROOT']}},
                {'POS': 'AUX', 'OP': '?'}  #Verbos auxiliar
                ]

matcherv = Matcher(nlp.vocab)

matcherv.add("sentença verbal", [gramaticav1])
matcherv.add("sentença verbal", [gramaticav2])
matcherv.add("sentença verbal", [gramaticav3])

#Retorna a Sentença Verbal
def localizaVerbos(sentenca):
  #Processa o período
  doc1 = nlp(sentenca)

  # Chama o matcher para encontrar o padrão
  matches = matcherv(doc1)

  padrao = [doc1[start:end] for _, start, end in matches]

  #elimina as repetições e sobreposições
  lista1 = filter_spans(padrao)

  # Converte os itens em string
  lista2 = []
  for x in lista1:
      lista2.append(str(x))

  return lista2

# %%
documento = "Vi, vi e venci."

verbos = localizaVerbos(documento)

print(verbos)
# Out:
# ['Vi', 'vi', 'venci']

# %% [markdown]
# # 4 Exemplo sentenças

# %% [markdown]
# ##Armazena um texto.

# %%
#documento = u"Estou bem, mas não tenho certeza se viajarei para São Paulo amanhã às 8:30."
#documento = u"Que é época de alta circulação de vírus respiratórios, apontam séries históricas da Fiocruz."
#documento = u'Olá Professor Osmar, hoje teremos aula?'
#documento = u'Professor, como eu faço para Empilhar um elemento de uma Fila?'
#documento = u'Olá Professor tudo bem? Como eu faço para Empilhar um elemento de uma Fila? Boa Tarde!'
#documento = u"O cão roía o osso."
#documento = u"O rato comeu o queijo."
documento = u"O que é uma pilha e como empilhar seu elemento?"

# %%
doc = nlp(documento)

logging.info('Texto armazenado!')
# Out:
# INFO:root:Texto armazenado!

# %% [markdown]
# ##Visualizando as dependências
#
# Éo processo de representar as dependências do texto através das relações entre os tokens. Por exemplo: um artigo está ligado a um substantivo, um advérbio modifica um verbo, e assim por diante.
#
# O significado das classes estão em: https://spacy.io/api/annotation#pos-tagging

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="5d2511a712ea48b9a418febd5b0415b5-0" class="displacy" width="1050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">é</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">pilha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">como</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">empilhar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">seu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">elemento?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-0" stroke-width="2px" d="M170,202.0 C170,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-1" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-2" stroke-width="2px" d="M370,202.0 C370,152.0 435.0,152.0 435.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-3" stroke-width="2px" d="M70,202.0 C70,2.0 450.0,2.0 450.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl:relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,204.0 L458.0,192.0 442.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-4" stroke-width="2px" d="M570,202.0 C570,102.0 740.0,102.0 740.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,204.0 L562,192.0 578,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-5" stroke-width="2px" d="M670,202.0 C670,152.0 735.0,152.0 735.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,204.0 L662,192.0 678,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-6" stroke-width="2px" d="M470,202.0 C470,52.0 745.0,52.0 745.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,204.0 L753.0,192.0 737.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-7" stroke-width="2px" d="M870,202.0 C870,152.0 935.0,152.0 935.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,204.0 L862,192.0 878,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5d2511a712ea48b9a418febd5b0415b5-0-8" stroke-width="2px" d="M770,202.0 C770,102.0 940.0,102.0 940.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5d2511a712ea48b9a418febd5b0415b5-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M940.0,204.0 L948.0,192.0 932.0,192.0" fill="currentColor"/>

# %% [markdown]
# ##Armazena um texto.

# %%
#documento = u"Estou bem, mas não tenho certeza se viajarei para São Paulo amanhã às 8:30."
#documento = u"Que é época de alta circulação de vírus respiratórios, apontam séries históricas da Fiocruz."
#documento = u'Olá Professor Osmar, hoje teremos aula?'
#documento = u'Professor, como eu faço para Empilhar um elemento de uma Fila?'
#documento = u'Olá Professor tudo bem? Como eu faço para Empilhar um elemento de uma Fila? Boa Tarde!'
#documento = u"O cão roía o osso."
#documento = u"O rato comeu o queijo."
documento = u"O que é uma fila e como enfileirar seu elemento?"

# %%
doc = nlp(documento)

logging.info('Texto armazenado!')
# Out:
# INFO:root:Texto armazenado!

# %% [markdown]
# ##Visualizando as dependências
#
# Éo processo de representar as dependências do texto através das relações entre os tokens. Por exemplo: um artigo está ligado a um substantivo, um advérbio modifica um verbo, e assim por diante.
#
# O significado das classes estão em: https://spacy.io/api/annotation#pos-tagging

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="7d740d32bea04a019dc4f3c299305436-0" class="displacy" width="1050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">é</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">uma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">fila</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">como</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">enfileirar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">seu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">elemento?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-0" stroke-width="2px" d="M170,202.0 C170,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-1" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-2" stroke-width="2px" d="M370,202.0 C370,152.0 435.0,152.0 435.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-3" stroke-width="2px" d="M70,202.0 C70,2.0 450.0,2.0 450.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl:relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,204.0 L458.0,192.0 442.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-4" stroke-width="2px" d="M570,202.0 C570,102.0 740.0,102.0 740.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,204.0 L562,192.0 578,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-5" stroke-width="2px" d="M670,202.0 C670,152.0 735.0,152.0 735.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,204.0 L662,192.0 678,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-6" stroke-width="2px" d="M470,202.0 C470,52.0 745.0,52.0 745.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,204.0 L753.0,192.0 737.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-7" stroke-width="2px" d="M870,202.0 C870,152.0 935.0,152.0 935.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,204.0 L862,192.0 878,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d740d32bea04a019dc4f3c299305436-0-8" stroke-width="2px" d="M770,202.0 C770,102.0 940.0,102.0 940.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d740d32bea04a019dc4f3c299305436-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M940.0,204.0 L948.0,192.0 932.0,192.0" fill="currentColor"/

# %% [markdown]
# ##Árvore de Análise

# %%
#documento = u"Que dia bonito hoje!"
#documento = u"Que é época de alta circulação de vírus respiratórios, apontam séries históricas da Fiocruz."
#documento = u"Estou bem, mas não tenho certeza se viajarei para São Paulo amanhã às 8:30."
#documento = u"Estados anunciam flexibilização em época de alta circulação de vírus respiratórios, apontam séries históricas da Fiocruz."
documento = u"O que é uma pilha e como empilhar seu elemento?"

doc = nlp(documento)

print (type(doc))

if (type(doc) is spacy.tokens.doc.Doc):
  print("tipo Spacy")
else:
  print("Não é do tipo spacy")
# Out:
# <class 'spacy.tokens.doc.Doc'>
# tipo Spacy

# %%
# Importando as bibliotecas.
import spacy
from nltk import Tree

def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_

# %%
print([to_nltk_tree(sent.root).pretty_print() for sent in doc.sents])
# Out:
#      O
#   ___|________
#  |          pilha
#  |    ________|__________
#  |   |   |    |       empilhar
#  |   |   |    |     _____|________
#  |   |   |    |    |     |     elemento
#  |   |   |    |    |     |        |
#  ?  que  é   uma   e    como     seu
#
# [None]

# %% [markdown]
# # 5 Exemplo comparando os embeddings das ocorrências da palavra "banco" em uma sentença.

# %% [markdown]
# ## Comparando embeddings de palavras

# %%
texto = "Depois de roubar o cofre do banco,"\
        " o ladrão de banco foi visto " \
        "sentado no banco da praça central."

logging.info('Texto armazenado!')
# Out:
# INFO:root:Texto armazenado!

# %%
doc = nlp(texto)

# %% [markdown]
# Confirmando os tokens do documento

# %%
i = 0
for token in doc:
   print(i, token)
   i = i + 1
# Out:
# 0 Depois
# 1 de
# 2 roubar
# 3 o
# 4 cofre
# 5 do
# 6 banco
# 7 ,
# 8 o
# 9 ladrão
# 10 de
# 11 banco
# 12 foi
# 13 visto
# 14 sentado
# 15 no
# 16 banco
# 17 da
# 18 praça
# 19 central
# 20 .

# %% [markdown]
# Exibe os embenddings das palavras

# %% [markdown]
# A banco aparece nos índices 6, 11 e 16.

# %%
# Índice das palavras a serem comparadas
palavra1 = 6
palavra2 = 11
palavra3 = 16

print("Os primeiros 5 valores de cada instância de \"banco\".")
print("")
print(str(doc[palavra1]), doc[palavra1].vector[:5])
print(str(doc[palavra2]), doc[palavra3].vector[:5])
print(str(doc[palavra3]), doc[palavra2].vector[:5])
# Out:
# Os primeiros 5 valores de cada instância de "banco".
#
# banco [-0.9601  -3.2818  -1.357   -0.91696  3.5838 ]
# banco [-0.9601  -3.2818  -1.357   -0.91696  3.5838 ]
# banco [-0.9601  -3.2818  -1.357   -0.91696  3.5838 ]

# %%
# Índice das palavras a serem comparadas
print("Período:", texto)
print("Palavra 1 =", palavra1, "=", str(doc[palavra1]), "(instituição financeira)")
print("Palavra 2 =", palavra2, "=", str(doc[palavra2]), "(instituição financeira)")
print("Palavra 3 =", palavra3, "=", str(doc[palavra3]), "(assento)")

# Calcula a similaridade de coseno entre as palavras banco
# Em "ladrão de banco" versus "banco da praça" (diferentes significados).
banco_diferente = doc[palavra2].similarity(doc[palavra3])

print("Vetor de similaridade  para diferentes significados(",palavra2,",",palavra3,"):  %.2f" % banco_diferente)

# Calcula a similaridade de coseno entre as palavras banco
# Em "ladrão de banco" versus "cofre do banco" (mesmo significado).
mesmo_banco = doc[palavra2].similarity(doc[palavra1])

print("Vetor de similaridade  para mesmo significado(",palavra2,",",palavra1,"):  %.2f" % mesmo_banco)

# Calcula a similaridade de coseno entre as palavras banco
# Em "cofre do banco" versus "banco da praça" (diferente significados).
banco_diferente2 = doc[palavra3].similarity(doc[palavra1])

print("Vetor de similaridade  para diferentes significados(",palavra3,",",palavra1,"):  %.2f" % banco_diferente2)
# Out:
# Período: Depois de roubar o cofre do banco, o ladrão de banco foi visto sentado no banco da praça central.
# Palavra 1 = 6 = banco (instituição financeira)
# Palavra 2 = 11 = banco (instituição financeira)
# Palavra 3 = 16 = banco (assento)
# Vetor de similaridade  para diferentes significados( 11 , 16 ):  1.00
# Vetor de similaridade  para mesmo significado( 11 , 6 ):  1.00
# Vetor de similaridade  para diferentes significados( 16 , 6 ):  1.00

# %% [markdown]
# # 6 Exemplo comparando embeddings de palavras diferentes

# %% [markdown]
# ## Comparando palavras diferentes

# %% [markdown]
# Import para apresentação dos dados

# %%
# Importando as bibliotecas.
from scipy import spatial
from jinja2 import Template
from IPython.display import display, HTML

logging.info('Import realizado!')
# Out:
# INFO:root:Import realizado!

# %% [markdown]
# Função para calcular a similaridade e apresentação dos dados.

# %%
#template de apresentação dos dados
table_list_template = """
<table>
        <tr>
           <th>Palavra</th>
           <th>Similaridade</th>
        </tr>
        {% for item in items%}
        <TR>
           <TD class="c1">{{item[0].text}}</TD>
           <TD class="c2">{{item[1]}}</TD>
        </TR>
        {% endfor %}
</table>
"""

#função de cálculo da das palavras
def most_similar(positive, negative):
    cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)

    #recupera o cálculo das palavras
    positivo1 = nlp.vocab[positive[0]].vector
    positivo2 = nlp.vocab[positive[1]].vector
    negativo1 = nlp.vocab[negative[0]].vector

    # Agora precisamos encontrar o vetor mais próximo no vocabulário do resultado de "man" - "woman" + "queen"
    diferenca = negativo1 - positivo2 + positivo1

    cs = []
    for word in nlp.vocab:
        # Ignore palavras sem vetor
        if not word.has_vector:
            continue

        similarity = cosine_similarity(diferenca, word.vector)
        cs.append((word, similarity))

    cs = sorted(cs, key=lambda item: -item[1])

    tmpl = Template(table_list_template)
    output_html = tmpl.render(items=cs[:10])
    return HTML(output_html)

logging.info('Função criada!')
# Out:
# INFO:root:Função criada!

# %% [markdown]
# Similaridade de "queen" e "king"<br>
# Rainha + Mulher – Homem = ?

# %%
most_similar(positive=[u'rainha',u'mulher'], negative=[u'homem'])
# Out:
# <table>
#         <tr>
#            <th>Palavra</th>
#            <th>Similaridade</th>
#         </tr>
#
#         <TR>
#            <TD class="c1">homem</TD>
#            <TD class="c2">0.65435696</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">rainha</TD>
#            <TD class="c2">0.63287497</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">ladrão</TD>
#            <TD class="c2">0.39399546</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">dom</TD>
#            <TD class="c2">0.38642812</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">céu</TD>
#            <TD class="c2">0.36699665</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">D.</TD>
#            <TD class="c2">0.3281002</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">sentado</TD>
#            <TD class="c2">0.2875048</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">d.</TD>
#            <TD class="c2">0.24366677</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">elemento</TD>
#            <TD class="c2">0.2368108</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">v.v</TD>
#            <TD class="c2">0.23499781</TD>
#         </TR>
#
# </table>

# %% [markdown]
# Rainha + Homem – Mulher = ?

# %%
most_similar(positive=[u'rainha',u'homen'], negative=[u'mulher'])
# Out:
# <table>
#         <tr>
#            <th>Palavra</th>
#            <th>Similaridade</th>
#         </tr>
#
#         <TR>
#            <TD class="c1">rainha</TD>
#            <TD class="c2">0.8429845</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">mulher</TD>
#            <TD class="c2">0.74813455</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">sra.</TD>
#            <TD class="c2">0.37973404</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">Sra.</TD>
#            <TD class="c2">0.35056645</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">homem</TD>
#            <TD class="c2">0.32568753</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">pilha</TD>
#            <TD class="c2">0.28417754</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">D.</TD>
#            <TD class="c2">0.28291935</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">Sra</TD>
#            <TD class="c2">0.27065104</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">sra</TD>
#            <TD class="c2">0.25299478</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">certeza</TD>
#            <TD class="c2">0.2419604</TD>
#         </TR>
#
# </table>

# %% [markdown]
# Rei + Mulher – Homem = ?

# %%
most_similar(positive=[u'rei',u'mulher'], negative=[u'homem'])
# Out:
# <table>
#         <tr>
#            <th>Palavra</th>
#            <th>Similaridade</th>
#         </tr>
#
#         <TR>
#            <TD class="c1">rei</TD>
#            <TD class="c2">0.9311677</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">homem</TD>
#            <TD class="c2">0.55031234</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">rainha</TD>
#            <TD class="c2">0.39487094</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">D.</TD>
#            <TD class="c2">0.37275463</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">ladrão</TD>
#            <TD class="c2">0.3627836</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">v.v</TD>
#            <TD class="c2">0.3469931</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">dom</TD>
#            <TD class="c2">0.34520942</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">homen</TD>
#            <TD class="c2">0.30901098</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">d.</TD>
#            <TD class="c2">0.30572623</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">céu</TD>
#            <TD class="c2">0.29148066</TD>
#         </TR>
#
# </table>

# %% [markdown]
# Rei + Homem – Mulher = ?

# %%
most_similar(positive=[u'rei',u'homem'], negative=[u'mulher'])
# Out:
# <table>
#         <tr>
#            <th>Palavra</th>
#            <th>Similaridade</th>
#         </tr>
#
#         <TR>
#            <TD class="c1">rei</TD>
#            <TD class="c2">0.8917217</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">rainha</TD>
#            <TD class="c2">0.7386541</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">D.</TD>
#            <TD class="c2">0.46361017</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">d.</TD>
#            <TD class="c2">0.38125312</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">mulher</TD>
#            <TD class="c2">0.3643728</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">(;</TD>
#            <TD class="c2">0.30199814</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">r.</TD>
#            <TD class="c2">0.28308493</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">v.v</TD>
#            <TD class="c2">0.2759232</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">c.</TD>
#            <TD class="c2">0.23240358</TD>
#         </TR>
#
#         <TR>
#            <TD class="c1">homen</TD>
#            <TD class="c2">0.22730857</TD>
#         </TR>
#
# </table>

# %% [markdown]
# Função de cálculo da similaridade de palavras.

# %%
#Matemática de Word Embeding
from scipy import spatial

cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)

#recupera o cálculo das palavras
man = nlp.vocab[u'homem'].vector
woman = nlp.vocab[u'mulher'].vector
queen = nlp.vocab[u'rainha'].vector
#king = nlp.vocab[u'rei'].vector

# Agora precisamos encontrar o vetor mais próximo no vocabulário do resultado de "man" - "woman" + "queen"
maybe_king = man - woman + queen
computed_similarities = []

for word in nlp.vocab:
    # Ignore palavras sem vetor
    if not word.has_vector:
        continue

    similarity = cosine_similarity(maybe_king, word.vector)
    computed_similarities.append((word, similarity))

computed_similarities = sorted(computed_similarities, key=lambda item: -item[1])

#mostra o resultado
print([w[0].text for w in computed_similarities[:10]])
# Out:
# ['rei', 'homem', 'rainha', 'ladrão', 'dom', 'céu', 'homen', 'D.', 'sentado', 'd.']

# %% [markdown]
# Calculando a similaridade

# %%
banana = nlp.vocab[u'banana']
dog = nlp.vocab[u'cachorro']
fruit = nlp.vocab[u'fruta']
animal = nlp.vocab[u'animal']

print(dog.similarity(animal), dog.similarity(fruit))
print(banana.similarity(fruit), banana.similarity(animal))
# Out:
# 0.6258523464202881 0.23907972872257233
# 0.7187858819961548 0.17296834290027618

# %% [markdown]
# Calculando a similaridade entre textos

# %%
destino = nlp(u'Gatos são bonitos animais.')

doc1 = nlp(u'Cães são incríveis.')
doc2 = nlp(u'Algumas criaturas lindas são felinos.')
doc3 = nlp(u'Golfinhos são animais que nadam.')

print(destino.similarity(doc1))
print(destino.similarity(doc2))
print(destino.similarity(doc3))
# Out:
# 0.9246653318405151
# 0.8842596411705017
# 0.864515483379364
